# %% [markdown]
# # import necessary packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # load dataset

# %%
iris = pd.read_csv("C:/Iris.csv")
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # describing iris data 2 ways

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
description = iris.describe()
print(description)
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# # check for any null values 2 ways

# %%
iris.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
null_counts = iris.isnull().sum()
print(null_counts)
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# # Count and load iris

# %%
iris['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # scatterplot 2 ways(without and with hue and palette)

# %%
sns.scatterplot(x = 'sepal_length', y = 'petal_length', data = iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(x = 'sepal_length', y = 'petal_length', data = iris, hue = 'species', palette = 'rocket')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# # heatmap

# %%
sns.heatmap(iris.corr(), cbar=True, linewidth = 0.5)
# Out:
# C:\Users\Bhavik\AppData\Local\Temp\ipykernel_16140\3065681523.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(iris.corr(), cbar=True, linewidth = 0.5)
# <Axes: >

# %% [markdown]
# # creating countplot and pairplot with hue and palette

# %%
sns.countplot(x = 'species', hue = 'cyl', data = iris, palette)
# Out:
#   Cell In[12], line 1
#     sns.countplot(x = 'species', hue = 'cyl', data = iris, palette)
#                                                                   ^
# SyntaxError: positional argument follows keyword argument

# %%
sns.countplot(x='species', data=iris, palette = 'mako')
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
# Creating a pairplot with hue and palette
sns.pairplot(data=iris, hue='species', palette='icefire')

# %% [markdown]
# # To create color palette using cubehelix palette and an lmplot with hue and palette

# %%
sns.lmplot(x = 'petal_length', y = 'petal_width', data = iris, hue = "species", 
           sns.cubehelix_palette(start=2, rot=0, dark=0, light=.95, reverse=True, as_cmap=True))
# Out:
#   Cell In[15], line 2
#     sns.cubehelix_palette(start=2, rot=0, dark=0, light=.95, reverse=True, as_cmap=True))
#                                                                                         ^
# SyntaxError: positional argument follows keyword argument

# %%
#lmplot with hue and palette
sns.lmplot(x='petal_length', y='petal_width', data=iris, hue="species", 
           palette=sns.cubehelix_palette(start=2, rot=0, dark=0, light=.95, reverse=True, as_cmap=True))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 #lmplot with hue and palette
# ----> 2 sns.lmplot(x='petal_length', y='petal_width', data=iris, hue="species",
#       3            palette=sns.cubehelix_palette(start=2, rot=0, dark=0, light=.95, reverse=True, as_cmap=True))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
palette = sns.cubehelix_palette(start=2, rot=0, dark=0, light=.95, reverse=True)

# %%
sns.lmplot(x='petal_length', y='petal_width', data=iris, hue="species", palette=palette)
plt.show()

# %% [markdown]
# # boxplot

# %%
sns.boxplot(x = 'species', y = 'sepal_width', data=iris, palette='mako')
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %% [markdown]
# # Creating contour map with pairplot

# %%
sns.pairplot(iris, hue='species', palette = 'mako')

#this will print contour plots with each feature pair
for feature1 in iris.columns[:-1]:
    for feature2 in iris.columns[:-1]:
        if feature1 != feature2:
            plt.figure()
            sns.kdeplot(data=iris, x=feature1, y=feature2, hue='species',palette = 'mako', fill=True)
            plt.title(f'{feature1.capitalize()} vs {feature2.capitalize()}')
            
plt.show()

# %% [markdown]
# # Logistic Regression model, printing accuracy score, kneighbours classifier and decision tree classifier using train_test_split

# %%
from sklearn.model_selection import train_test_split
X = iris.drop(columns=['species'])
Y = iris['species']
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size=0.30)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # if the error in the above code in logistic regression occurs, we can set the solver parameter to liblinear

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='liblinear')

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
from sklearn.metrics import accuracy_score

# Predicting the target values for the test set
y_pred = model.predict(x_test)

# Calculating the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9777777777777777

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
print("Accuracy:", model.score(x_test, y_test) * 100)
# Out:
# Accuracy: 95.55555555555556

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy: ",model.score(x_test, y_test)* 100)
# Out:
# Accuracy:  95.55555555555556

# %% [markdown]
# # To create a confusion metrics using logistic regression and knn(K Nearest Neighbour)

# %%
from sklearn.metrics import confusion_matrix
logistic_model = LogisticRegression()
logistic_model.fit(x_train, y_train)
logistic_predictions = logistic_model.predict(x_test)

# Computing confusion matrix
logistic_cm = confusion_matrix(y_test, logistic_predictions)
print("Confusion Matrix - Logistic Regression:")
print(logistic_cm)
# Out:
# Confusion Matrix - Logistic Regression:
# [[13  0  0]
#  [ 0 13  0]
#  [ 0  2 17]]

# %% [markdown]
# # The k-nearest neighbors algorithm, also known as KNN or k-NN, is a non-parametric, supervised learning classifier, which uses proximity to make classifications or predictions about the grouping of an individual data point.

# %%
knn_model = KNeighborsClassifier()
knn_model.fit(x_train, y_train)
knn_predictions = knn_model.predict(x_test)

# Computing confusion matrix
knn_cm = confusion_matrix(y_test, knn_predictions)
print("Confusion Matrix - KNN:")
print(knn_cm)
# Out:
# Confusion Matrix - KNN:
# [[13  0  0]
#  [ 0 12  1]
#  [ 0  1 18]]

# %% [markdown]
# # To calculate mean and standard deviation using cross validation accuracy

# %%
from sklearn.model_selection import cross_val_score

# Creating the logistic regression model with increased max_iter
model = LogisticRegression(solver='lbfgs', max_iter=1000)  # We can adjust max_iter to a higher value

# Performing cross-validation with 5 folds
cv_scores = cross_val_score(model, x_train, y_train, cv=5)

# Calculating the mean and standard deviation of the cross-validation scores
mean_cv_score = cv_scores.mean()
std_cv_score = cv_scores.std()

print(f"Mean Cross-Validation Accuracy: {mean_cv_score:.3f}")
print(f"Standard Deviation of Cross-Validation Accuracy: {std_cv_score:.3f}")
# Out:
# Mean Cross-Validation Accuracy: 0.943
# Standard Deviation of Cross-Validation Accuracy: 0.019
